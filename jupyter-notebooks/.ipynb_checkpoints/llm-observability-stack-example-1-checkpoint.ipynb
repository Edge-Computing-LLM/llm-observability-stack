# %%
from IPython.display import display, HTML

display(HTML("""
<style>
    /* Target the specific container for shell/terminal output */
    .jp-OutputArea-output pre {
        white-space: pre !important;
        overflow-x: auto !important;
        display: block !important;
        width: max-content;
        min-width: 100%;
    }
    /* Ensure the output area itself allows the scrollbar */
    .jp-OutputArea-child {
        overflow-x: auto !important;
    }
</style>
"""))
# Out:
# <style>
#     /* Target the specific container for shell/terminal output */
#     .jp-OutputArea-output pre {
#         white-space: pre !important;
#         overflow-x: auto !important;
#         display: block !important;
#         width: max-content;
#         min-width: 100%;
#     }
#     /* Ensure the output area itself allows the scrollbar */
#     .jp-OutputArea-child {
#         overflow-x: auto !important;
#     }
# </style>

# %%
# !kubectl get all -A
# Out:
# NAMESPACE              NAME                                                        READY   STATUS    RESTARTS         AGE
# kube-system            pod/coredns-695cbbfcb9-69w4k                                1/1     Running   20 (4h33m ago)   10d
# kube-system            pod/local-path-provisioner-546dfc6456-cbtgj                 1/1     Running   24 (4h33m ago)   10d
# kube-system            pod/metrics-server-c8774f4f4-z6lpm                          1/1     Running   37 (4h33m ago)   10d
# kube-system            pod/svclb-open-webui-b3bbb697-s889q                         1/1     Running   7 (4h33m ago)    2d4h
# llm-observability      pod/langchain-demo-5dc95b9dbf-8ttrx                         1/1     Running   0                158m
# llm-observability      pod/ollama-f4f5c6bfc-hwndk                                  1/1     Running   0                169m
# llm-observability      pod/open-webui-0                                            1/1     Running   0                3h39m
# llm-observability      pod/redis-74f6bcc68f-hr2kl                                  1/1     Running   8 (4h33m ago)    2d4h
# nvidia-device-plugin   pod/nvdp-node-feature-discovery-master-798cdbb948-7hpvg     1/1     Running   20 (4h33m ago)   8d
# nvidia-device-plugin   pod/nvdp-node-feature-discovery-worker-nwmm8                1/1     Running   45 (5h37m ago)   8d
# nvidia-device-plugin   pod/nvdp-nvidia-device-plugin-gpu-feature-discovery-pxw5v   2/2     Running   24 (4h33m ago)   6d
# nvidia-device-plugin   pod/nvdp-nvidia-device-plugin-mps-control-daemon-8t5p7      2/2     Running   6 (4h33m ago)    15h
# nvidia-device-plugin   pod/nvdp-nvidia-device-plugin-nc24z                         2/2     Running   24 (4h33m ago)   6d
#
# NAMESPACE              NAME                                         TYPE           CLUSTER-IP      EXTERNAL-IP     PORT(S)                  AGE
# default                service/kubernetes                           ClusterIP      10.43.0.1       <none>          443/TCP                  42d
# kube-system            service/kube-dns                             ClusterIP      10.43.0.10      <none>          53/UDP,53/TCP,9153/TCP   42d
# kube-system            service/metrics-server                       ClusterIP      10.43.76.246    <none>          443/TCP                  42d
# llm-observability      service/langchain-demo                       ClusterIP      10.43.119.169   <none>          8000/TCP                 7d9h
# llm-observability      service/ollama                               ClusterIP      10.43.54.34     <none>          11434/TCP                7d9h
# llm-observability      service/open-webui                           LoadBalancer   10.43.82.54     192.168.18.45   8080:30523/TCP           7d9h
# llm-observability      service/redis                                ClusterIP      10.43.172.215   <none>          6379/TCP                 2d4h
# nvidia-device-plugin   service/nvdp-node-feature-discovery-master   ClusterIP      10.43.247.117   <none>          8080/TCP                 8d
#
# NAMESPACE              NAME                                                             DESIRED   CURRENT   READY   UP-TO-DATE   AVAILABLE   NODE SELECTOR                 AGE
# kube-system            daemonset.apps/svclb-open-webui-b3bbb697                         1         1         1       1            1           <none>                        2d4h
# nvidia-device-plugin   daemonset.apps/nvdp-node-feature-discovery-worker                1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   daemonset.apps/nvdp-nvidia-device-plugin                         1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   daemonset.apps/nvdp-nvidia-device-plugin-gpu-feature-discovery   1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   daemonset.apps/nvdp-nvidia-device-plugin-mps-control-daemon      1         1         1       1            1           nvidia.com/mps.capable=true   10d
#
# NAMESPACE              NAME                                                 READY   UP-TO-DATE   AVAILABLE   AGE
# kube-system            deployment.apps/coredns                              1/1     1            1           42d
# kube-system            deployment.apps/local-path-provisioner               1/1     1            1           42d
# kube-system            deployment.apps/metrics-server                       1/1     1            1           42d
# llm-observability      deployment.apps/langchain-demo                       1/1     1            1           7d9h
# llm-observability      deployment.apps/ollama                               1/1     1            1           7d9h
# llm-observability      deployment.apps/redis                                1/1     1            1           2d4h
# nvidia-device-plugin   deployment.apps/nvdp-node-feature-discovery-master   1/1     1            1           10d
#
# NAMESPACE              NAME                                                            DESIRED   CURRENT   READY   AGE
# kube-system            replicaset.apps/coredns-695cbbfcb9                              1         1         1       10d
# kube-system            replicaset.apps/local-path-provisioner-546dfc6456               1         1         1       10d
# kube-system            replicaset.apps/metrics-server-c8774f4f4                        1         1         1       10d
# llm-observability      replicaset.apps/langchain-demo-5dc95b9dbf                       1         1         1       158m
# llm-observability      replicaset.apps/langchain-demo-698657b9cf                       0         0         0       6d1h
# llm-observability      replicaset.apps/langchain-demo-6c8f8f9c75                       0         0         0       3h39m
# llm-observability      replicaset.apps/langchain-demo-6db6df7f5b                       0         0         0       169m
# llm-observability      replicaset.apps/ollama-644cdfbf7f                               0         0         0       6d1h
# llm-observability      replicaset.apps/ollama-f4f5c6bfc                                1         1         1       169m
# llm-observability      replicaset.apps/redis-74f6bcc68f                                1         1         1       2d4h
# llm-observability      replicaset.apps/redis-76bff6668b                                0         0         0       2d4h
# nvidia-device-plugin   replicaset.apps/nvdp-node-feature-discovery-master-798cdbb948   1         1         1       8d
#
# NAMESPACE           NAME                          READY   AGE
# llm-observability   statefulset.apps/open-webui   1/1     7d9h

# %%
# !kubectl get pods -A
# Out:
# NAMESPACE              NAME                                                    READY   STATUS    RESTARTS         AGE
# kube-system            coredns-695cbbfcb9-69w4k                                1/1     Running   20 (4h58m ago)   10d
# kube-system            local-path-provisioner-546dfc6456-cbtgj                 1/1     Running   24 (4h58m ago)   10d
# kube-system            metrics-server-c8774f4f4-z6lpm                          1/1     Running   37 (4h58m ago)   10d
# kube-system            svclb-open-webui-b3bbb697-s889q                         1/1     Running   7 (4h58m ago)    2d5h
# llm-observability      langchain-demo-5dc95b9dbf-8ttrx                         1/1     Running   0                3h3m
# llm-observability      ollama-f4f5c6bfc-hwndk                                  1/1     Running   0                3h14m
# llm-observability      open-webui-0                                            1/1     Running   0                4h4m
# llm-observability      redis-74f6bcc68f-hr2kl                                  1/1     Running   8 (4h58m ago)    2d5h
# nvidia-device-plugin   nvdp-node-feature-discovery-master-798cdbb948-7hpvg     1/1     Running   20 (4h58m ago)   8d
# nvidia-device-plugin   nvdp-node-feature-discovery-worker-nwmm8                1/1     Running   45 (6h2m ago)    8d
# nvidia-device-plugin   nvdp-nvidia-device-plugin-gpu-feature-discovery-pxw5v   2/2     Running   24 (4h58m ago)   6d
# nvidia-device-plugin   nvdp-nvidia-device-plugin-mps-control-daemon-8t5p7      2/2     Running   6 (4h58m ago)    15h
# nvidia-device-plugin   nvdp-nvidia-device-plugin-nc24z                         2/2     Running   24 (4h58m ago)   6d

# %%
# !kubectl get services -A
# Out:
# NAMESPACE              NAME                                 TYPE           CLUSTER-IP      EXTERNAL-IP     PORT(S)                  AGE
# default                kubernetes                           ClusterIP      10.43.0.1       <none>          443/TCP                  42d
# kube-system            kube-dns                             ClusterIP      10.43.0.10      <none>          53/UDP,53/TCP,9153/TCP   42d
# kube-system            metrics-server                       ClusterIP      10.43.76.246    <none>          443/TCP                  42d
# llm-observability      langchain-demo                       ClusterIP      10.43.119.169   <none>          8000/TCP                 7d9h
# llm-observability      ollama                               ClusterIP      10.43.54.34     <none>          11434/TCP                7d9h
# llm-observability      open-webui                           LoadBalancer   10.43.82.54     192.168.18.45   8080:30523/TCP           7d9h
# llm-observability      redis                                ClusterIP      10.43.172.215   <none>          6379/TCP                 2d5h
# nvidia-device-plugin   nvdp-node-feature-discovery-master   ClusterIP      10.43.247.117   <none>          8080/TCP                 8d

# %%
# !kubectl get daemonset -A
# Out:
# NAMESPACE              NAME                                              DESIRED   CURRENT   READY   UP-TO-DATE   AVAILABLE   NODE SELECTOR                 AGE
# kube-system            svclb-open-webui-b3bbb697                         1         1         1       1            1           <none>                        2d5h
# nvidia-device-plugin   nvdp-node-feature-discovery-worker                1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   nvdp-nvidia-device-plugin                         1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   nvdp-nvidia-device-plugin-gpu-feature-discovery   1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   nvdp-nvidia-device-plugin-mps-control-daemon      1         1         1       1            1           nvidia.com/mps.capable=true   10d

# %%
# !kubectl get daemonSets -A
# Out:
# NAMESPACE              NAME                                              DESIRED   CURRENT   READY   UP-TO-DATE   AVAILABLE   NODE SELECTOR                 AGE
# kube-system            svclb-open-webui-b3bbb697                         1         1         1       1            1           <none>                        2d7h
# nvidia-device-plugin   nvdp-node-feature-discovery-worker                1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   nvdp-nvidia-device-plugin                         1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   nvdp-nvidia-device-plugin-gpu-feature-discovery   1         1         1       1            1           <none>                        10d
# nvidia-device-plugin   nvdp-nvidia-device-plugin-mps-control-daemon      1         1         1       1            1           nvidia.com/mps.capable=true   10d

# %%
# !kubectl get deployment -A
# Out:
# NAMESPACE              NAME                                 READY   UP-TO-DATE   AVAILABLE   AGE
# kube-system            coredns                              1/1     1            1           42d
# kube-system            local-path-provisioner               1/1     1            1           42d
# kube-system            metrics-server                       1/1     1            1           42d
# llm-observability      langchain-demo                       1/1     1            1           7d9h
# llm-observability      ollama                               1/1     1            1           7d9h
# llm-observability      redis                                1/1     1            1           2d5h
# nvidia-device-plugin   nvdp-node-feature-discovery-master   1/1     1            1           10d

# %%
# !kubectl get replicaset -A
# Out:
# NAMESPACE              NAME                                            DESIRED   CURRENT   READY   AGE
# kube-system            coredns-695cbbfcb9                              1         1         1       10d
# kube-system            local-path-provisioner-546dfc6456               1         1         1       10d
# kube-system            metrics-server-c8774f4f4                        1         1         1       10d
# llm-observability      langchain-demo-5dc95b9dbf                       1         1         1       3h6m
# llm-observability      langchain-demo-698657b9cf                       0         0         0       6d1h
# llm-observability      langchain-demo-6c8f8f9c75                       0         0         0       4h6m
# llm-observability      langchain-demo-6db6df7f5b                       0         0         0       3h16m
# llm-observability      ollama-644cdfbf7f                               0         0         0       6d1h
# llm-observability      ollama-f4f5c6bfc                                1         1         1       3h16m
# llm-observability      redis-74f6bcc68f                                1         1         1       2d5h
# llm-observability      redis-76bff6668b                                0         0         0       2d5h
# nvidia-device-plugin   nvdp-node-feature-discovery-master-798cdbb948   1         1         1       8d

# %%
# !kubectl get namespace -A
# Out:
# NAME                   STATUS   AGE
# default                Active   42d
# kube-node-lease        Active   42d
# kube-public            Active   42d
# kube-system            Active   42d
# llm-observability      Active   7d10h
# nvidia-device-plugin   Active   10d

# %%
# !kubectl get statefulset -A
# Out:
# NAMESPACE           NAME         READY   AGE
# llm-observability   open-webui   1/1     7d9h

# %%
# !kubectl get componentstatuses
# Out:
# Warning: v1 ComponentStatus is deprecated in v1.19+
# NAME                 STATUS    MESSAGE   ERROR
# etcd-0               Healthy   ok
# controller-manager   Healthy   ok
# scheduler            Healthy   ok

# %%
# !kubectl get nodes -A
# Out:
# NAME       STATUS   ROLES           AGE   VERSION
# waqasm86   Ready    control-plane   42d   v1.34.5+k3s1

# %%
# !kubectl get all -n kube-system
# Out:
# NAME                                          READY   STATUS    RESTARTS        AGE
# pod/coredns-695cbbfcb9-69w4k                  1/1     Running   20 (6h9m ago)   10d
# pod/local-path-provisioner-546dfc6456-cbtgj   1/1     Running   24 (6h9m ago)   10d
# pod/metrics-server-c8774f4f4-z6lpm            1/1     Running   37 (6h9m ago)   10d
# pod/svclb-open-webui-b3bbb697-s889q           1/1     Running   7 (6h9m ago)    2d6h
#
# NAME                     TYPE        CLUSTER-IP     EXTERNAL-IP   PORT(S)                  AGE
# service/kube-dns         ClusterIP   10.43.0.10     <none>        53/UDP,53/TCP,9153/TCP   42d
# service/metrics-server   ClusterIP   10.43.76.246   <none>        443/TCP                  42d
#
# NAME                                       DESIRED   CURRENT   READY   UP-TO-DATE   AVAILABLE   NODE SELECTOR   AGE
# daemonset.apps/svclb-open-webui-b3bbb697   1         1         1       1            1           <none>          2d6h
#
# NAME                                     READY   UP-TO-DATE   AVAILABLE   AGE
# deployment.apps/coredns                  1/1     1            1           42d
# deployment.apps/local-path-provisioner   1/1     1            1           42d
# deployment.apps/metrics-server           1/1     1            1           42d
#
# NAME                                                DESIRED   CURRENT   READY   AGE
# replicaset.apps/coredns-695cbbfcb9                  1         1         1       10d
# replicaset.apps/local-path-provisioner-546dfc6456   1         1         1       10d
# replicaset.apps/metrics-server-c8774f4f4            1         1         1       10d

# %%
# !journalctl -m -u k3s -u k3s-agent | grep 'Running kube-proxy' | tail -n1
# Out:
# مارچ 22 18:06:35 waqasm86 k3s[3465]: time="2026-03-22T18:06:35+05:00" level=info msg="Running kube-proxy --cluster-cidr=10.42.0.0/16 --conntrack-max-per-core=0 --conntrack-tcp-timeout-close-wait=0s --conntrack-tcp-timeout-established=0s --healthz-bind-address=127.0.0.1 --hostname-override=waqasm86 --kubeconfig=/var/lib/rancher/k3s/agent/kubeproxy.kubeconfig --proxy-mode=iptables"

# %%
# !kubectl get events -A
# Out:
# No resources found

# %%
# !kubectl get pv -A
# Out:
# NAME                                       CAPACITY   ACCESS MODES   RECLAIM POLICY   STATUS   CLAIM                          STORAGECLASS   VOLUMEATTRIBUTESCLASS   REASON   AGE
# pvc-02356881-9faf-4e02-ac4b-1f9476ddda9a   5Gi        RWO            Delete           Bound    llm-observability/redis-data   local-path     <unset>                          2d7h
# pvc-2605b535-8539-4d1f-a42e-cd7ffa75090e   5Gi        RWO            Delete           Bound    llm-observability/open-webui   local-path     <unset>                          7d11h
# pvc-3c945965-acd3-4aee-a8d1-3878ffc20a65   20Gi       RWO            Delete           Bound    llm-observability/ollama       local-path     <unset>                          7d10h

# %%
# !kubectl get pvc -A
# Out:
# NAMESPACE           NAME         STATUS   VOLUME                                     CAPACITY   ACCESS MODES   STORAGECLASS   VOLUMEATTRIBUTESCLASS   AGE
# llm-observability   ollama       Bound    pvc-3c945965-acd3-4aee-a8d1-3878ffc20a65   20Gi       RWO            local-path     <unset>                 7d11h
# llm-observability   open-webui   Bound    pvc-2605b535-8539-4d1f-a42e-cd7ffa75090e   5Gi        RWO            local-path     <unset>                 7d11h
# llm-observability   redis-data   Bound    pvc-02356881-9faf-4e02-ac4b-1f9476ddda9a   5Gi        RWO            local-path     <unset>                 2d6h

# %%
# !kubectl describe pods -n llm-observability
# Out:
# Name:             langchain-demo-5dc95b9dbf-8ttrx
# Namespace:        llm-observability
# Priority:         0
# Service Account:  default
# Node:             waqasm86/192.168.18.45
# Start Time:       Sun, 22 Mar 2026 20:01:12 +0500
# Labels:           app.kubernetes.io/name=langchain-demo
#                   pod-template-hash=5dc95b9dbf
# Annotations:      <none>
# Status:           Running
# IP:               10.42.0.96
# IPs:
#   IP:           10.42.0.96
# Controlled By:  ReplicaSet/langchain-demo-5dc95b9dbf
# Containers:
#   app:
#     Container ID:  containerd://8c8345233961fc38e400aea4ff95fc5b9c716442b6f90db8e3d6020790ac1ac2
#     Image:         langchain-demo:0.1.0
#     Image ID:      sha256:ba7d1f2f803678bc860c4cde3dcb1555e2657cdb40b910d18157324a17509d8a
#     Port:          8000/TCP (http)
#     Host Port:     0/TCP (http)
#     Command:
#       python
#       -m
#       uvicorn
#       app:app
#       --host
#       0.0.0.0
#       --port
#       8000
#       --workers
#       1
#     State:          Running
#       Started:      Sun, 22 Mar 2026 20:01:13 +0500
#     Ready:          True
#     Restart Count:  0
#     Limits:
#       cpu:     1
#       memory:  1Gi
#     Requests:
#       cpu:      250m
#       memory:   512Mi
#     Liveness:   http-get http://:http/healthz delay=40s timeout=1s period=20s #success=1 #failure=3
#     Readiness:  http-get http://:http/healthz delay=20s timeout=1s period=10s #success=1 #failure=3
#     Startup:    http-get http://:http/healthz delay=30s timeout=1s period=10s #success=1 #failure=36
#     Environment:
#       OLLAMA_BASE_URL:               http://ollama:11434
#       OLLAMA_UPSTREAM_BASE_URL:      http://ollama:11434
#       OLLAMA_MODEL:                  gemma3-1b-it-gguf-local
#       OLLAMA_PROXY_PATH_PREFIX:      /ollama
#       OLLAMA_PROXY_TRACE_LANGSMITH:  true
#       OLLAMA_PROXY_TIMEOUT_SECONDS:  180
#       LANGSMITH_TRACING:             true
#       LANGCHAIN_TRACING_V2:          true
#       LANGSMITH_ENDPOINT:            https://api.smith.langchain.com
#       LANGCHAIN_ENDPOINT:            https://api.smith.langchain.com
#       LANGSMITH_PROJECT:             k3s-ollama-gemma-local
#       LANGCHAIN_PROJECT:             k3s-ollama-gemma-local
#       LANGSMITH_API_KEY:             <set to the key 'LANGSMITH_API_KEY' in secret 'langsmith-secrets'>  Optional: false
#       LANGCHAIN_API_KEY:             <set to the key 'LANGSMITH_API_KEY' in secret 'langsmith-secrets'>  Optional: false
#     Mounts:
#       /app/app.py from app-code (ro,path="app.py")
#       /var/run/secrets/kubernetes.io/serviceaccount from kube-api-access-brcxt (ro)
# Conditions:
#   Type                        Status
#   PodReadyToStartContainers   True
#   Initialized                 True
#   Ready                       True
#   ContainersReady             True
#   PodScheduled                True
# Volumes:
#   app-code:
#     Type:      ConfigMap (a volume populated by a ConfigMap)
#     Name:      langchain-demo-app
#     Optional:  false
#   kube-api-access-brcxt:
#     Type:                    Projected (a volume that contains injected data from multiple sources)
#     TokenExpirationSeconds:  3607
#     ConfigMapName:           kube-root-ca.crt
#     Optional:                false
#     DownwardAPI:             true
# QoS Class:                   Burstable
# Node-Selectors:              <none>
# Tolerations:                 node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                              node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
# Events:
#   Type     Reason     Age                  From     Message
#   ----     ------     ----                 ----     -------
#   Warning  Unhealthy  32m (x5 over 5h6m)   kubelet  Liveness probe failed: Get "http://10.42.0.96:8000/healthz": context deadline exceeded (Client.Timeout exceeded while awaiting headers)
#   Warning  Unhealthy  32m (x10 over 5h6m)  kubelet  Readiness probe failed: Get "http://10.42.0.96:8000/healthz": context deadline exceeded (Client.Timeout exceeded while awaiting headers)
#
#
# Name:                ollama-f4f5c6bfc-hwndk
# Namespace:           llm-observability
# Priority:            0
# Runtime Class Name:  nvidia
# Service Account:     ollama
# Node:                waqasm86/192.168.18.45
# Start Time:          Sun, 22 Mar 2026 19:50:23 +0500
# Labels:              app.kubernetes.io/instance=llm-observability-stack
#                      app.kubernetes.io/managed-by=Helm
#                      app.kubernetes.io/name=ollama
#                      app.kubernetes.io/version=0.17.7
#                      helm.sh/chart=ollama-1.50.0
#                      pod-template-hash=f4f5c6bfc
# Annotations:         <none>
# Status:              Running
# IP:                  10.42.0.92
# IPs:
#   IP:           10.42.0.92
# Controlled By:  ReplicaSet/ollama-f4f5c6bfc
# Containers:
#   ollama:
#     Container ID:   containerd://76d08c16bfd7f912dab75db07bdfaece7a1744576d286fe1d19d88d9befdea05
#     Image:          ollama/ollama:0.17.7
#     Image ID:       docker.io/ollama/ollama@sha256:0ff452f6a4c3c5bb4ab063a1db190b261d5834741a519189ed5301d50e4434d1
#     Port:           11434/TCP (http)
#     Host Port:      0/TCP (http)
#     State:          Running
#       Started:      Sun, 22 Mar 2026 19:50:25 +0500
#     Ready:          True
#     Restart Count:  0
#     Limits:
#       cpu:                    4
#       memory:                 8Gi
#       nvidia.com/gpu.shared:  1
#     Requests:
#       cpu:                    1
#       memory:                 2Gi
#       nvidia.com/gpu.shared:  1
#     Liveness:                 http-get http://:http/ delay=60s timeout=5s period=10s #success=1 #failure=6
#     Readiness:                http-get http://:http/ delay=30s timeout=3s period=5s #success=1 #failure=6
#     Environment:
#       OLLAMA_HOST:               0.0.0.0:11434
#       PATH:                      /usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
#       OLLAMA_KEEP_ALIVE:         30s
#       OLLAMA_NUM_PARALLEL:       1
#       OLLAMA_MAX_LOADED_MODELS:  1
#     Mounts:
#       /models from gemma3-1b-it-gguf-local-config-model-volume (rw)
#       /models/gguf from local-gguf-model (ro)
#       /root/.ollama from ollama-data (rw)
#       /var/run/secrets/kubernetes.io/serviceaccount from kube-api-access-kjdzk (ro)
# Conditions:
#   Type                        Status
#   PodReadyToStartContainers   True
#   Initialized                 True
#   Ready                       True
#   ContainersReady             True
#   PodScheduled                True
# Volumes:
#   ollama-data:
#     Type:       PersistentVolumeClaim (a reference to a PersistentVolumeClaim in the same namespace)
#     ClaimName:  ollama
#     ReadOnly:   false
#   gemma3-1b-it-gguf-local-config-model-volume:
#     Type:      ConfigMap (a volume populated by a ConfigMap)
#     Name:      ollama-local-modelfile
#     Optional:  false
#   local-gguf-model:
#     Type:          HostPath (bare host directory volume)
#     Path:          /media/waqasm86/External1/Project-Nvidia-Office/Project-Llamatelemetry/langchain-kubernetes-jupyterlab/gguf-models
#     HostPathType:  Directory
#   kube-api-access-kjdzk:
#     Type:                    Projected (a volume that contains injected data from multiple sources)
#     TokenExpirationSeconds:  3607
#     ConfigMapName:           kube-root-ca.crt
#     Optional:                false
#     DownwardAPI:             true
# QoS Class:                   Burstable
# Node-Selectors:              <none>
# Tolerations:                 node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                              node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
#                              nvidia.com/gpu.shared:NoSchedule op=Exists
# Events:                      <none>
#
#
# Name:             open-webui-0
# Namespace:        llm-observability
# Priority:         0
# Service Account:  open-webui-sa
# Node:             waqasm86/192.168.18.45
# Start Time:       Sun, 22 Mar 2026 19:00:27 +0500
# Labels:           app.kubernetes.io/component=open-webui
#                   app.kubernetes.io/instance=llm-observability-stack
#                   app.kubernetes.io/managed-by=Helm
#                   app.kubernetes.io/name=open-webui
#                   app.kubernetes.io/version=0.8.10
#                   apps.kubernetes.io/pod-index=0
#                   controller-revision-hash=open-webui-dbd944db
#                   helm.sh/chart=open-webui-12.10.0
#                   statefulset.kubernetes.io/pod-name=open-webui-0
# Annotations:      <none>
# Status:           Running
# IP:               10.42.0.79
# IPs:
#   IP:           10.42.0.79
# Controlled By:  StatefulSet/open-webui
# Init Containers:
#   copy-app-data:
#     Container ID:  containerd://fa887cefae94f7db5ae4219b70b42834267f87b1839661781f326c6e7cc25e8e
#     Image:         ghcr.io/open-webui/open-webui:0.8.10
#     Image ID:      ghcr.io/open-webui/open-webui@sha256:ee057955040ce91e3e787e4b7978c9c23e828972c68d01d787ed40f9a307df9f
#     Port:          <none>
#     Host Port:     <none>
#     Command:
#       sh
#       -c
#       cp -R -n /app/backend/data/* /tmp/app-data/
#     State:          Terminated
#       Reason:       Completed
#       Exit Code:    0
#       Started:      Sun, 22 Mar 2026 19:00:28 +0500
#       Finished:     Sun, 22 Mar 2026 19:00:28 +0500
#     Ready:          True
#     Restart Count:  0
#     Environment:    <none>
#     Mounts:
#       /tmp/app-data from data (rw)
# Containers:
#   open-webui:
#     Container ID:   containerd://229c703b613aeb443fbc5f371300744f55447d4bd116dd6afbad76122f68489a
#     Image:          ghcr.io/open-webui/open-webui:0.8.10
#     Image ID:       ghcr.io/open-webui/open-webui@sha256:ee057955040ce91e3e787e4b7978c9c23e828972c68d01d787ed40f9a307df9f
#     Port:           8080/TCP (http)
#     Host Port:      0/TCP (http)
#     State:          Running
#       Started:      Sun, 22 Mar 2026 19:00:29 +0500
#     Ready:          True
#     Restart Count:  0
#     Limits:
#       cpu:     1500m
#       memory:  2Gi
#     Requests:
#       cpu:     500m
#       memory:  1Gi
#     Environment:
#       OLLAMA_BASE_URLS:          http://langchain-demo:8000/ollama
#       ENABLE_OPENAI_API:         False
#       ENABLE_WEBSOCKET_SUPPORT:  True
#       WEBSOCKET_MANAGER:         redis
#       REDIS_URL:                 redis://openwebui:saqaw20@redis.llm-observability.svc.cluster.local:6379/0
#       WEBSOCKET_REDIS_URL:       redis://openwebui:saqaw20@redis.llm-observability.svc.cluster.local:6379/0
#       OLLAMA_BASE_URL:           http://langchain-demo:8000/ollama
#       ENABLE_PERSISTENT_CONFIG:  False
#       WEBUI_AUTH:                False
#       WEBUI_SECRET_KEY:          <set to the key 'WEBUI_SECRET_KEY' in secret 'open-webui-secrets'>  Optional: false
#     Mounts:
#       /app/backend/data from data (rw)
# Conditions:
#   Type                        Status
#   PodReadyToStartContainers   True
#   Initialized                 True
#   Ready                       True
#   ContainersReady             True
#   PodScheduled                True
# Volumes:
#   data:
#     Type:        PersistentVolumeClaim (a reference to a PersistentVolumeClaim in the same namespace)
#     ClaimName:   open-webui
#     ReadOnly:    false
# QoS Class:       Burstable
# Node-Selectors:  <none>
# Tolerations:     node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                  node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
# Events:          <none>
#
#
# Name:             redis-74f6bcc68f-hr2kl
# Namespace:        llm-observability
# Priority:         0
# Service Account:  default
# Node:             waqasm86/192.168.18.45
# Start Time:       Fri, 20 Mar 2026 17:59:23 +0500
# Labels:           app.kubernetes.io/name=redis
#                   pod-template-hash=74f6bcc68f
# Annotations:      <none>
# Status:           Running
# IP:               10.42.0.64
# IPs:
#   IP:           10.42.0.64
# Controlled By:  ReplicaSet/redis-74f6bcc68f
# Containers:
#   redis:
#     Container ID:  containerd://cabdd837aa16c48bda12e019cc520a38780a37d9640e66ccdff35c203fe512ec
#     Image:         redis:7-alpine
#     Image ID:      docker.io/library/redis@sha256:8b81dd37ff027bec4e516d41acfbe9fe2460070dc6d4a4570a2ac5b9d59df065
#     Port:          6379/TCP (redis)
#     Host Port:     0/TCP (redis)
#     Command:
#       /bin/sh
#       -ec
#       if [ "${REDIS_AUTH_ENABLED}" = "true" ]; then
#         printf 'user default off\nuser %s on >%s ~* &* +@all\n' "${REDIS_USERNAME}" "${REDIS_PASSWORD}" > /tmp/users.acl
#         exec redis-server /usr/local/etc/redis/redis.conf --aclfile /tmp/users.acl
#       fi
#       exec redis-server /usr/local/etc/redis/redis.conf
#
#     State:          Running
#       Started:      Sun, 22 Mar 2026 18:06:44 +0500
#     Last State:     Terminated
#       Reason:       Unknown
#       Exit Code:    255
#       Started:      Sun, 22 Mar 2026 15:33:33 +0500
#       Finished:     Sun, 22 Mar 2026 18:06:36 +0500
#     Ready:          True
#     Restart Count:  8
#     Limits:
#       cpu:     500m
#       memory:  512Mi
#     Requests:
#       cpu:     250m
#       memory:  256Mi
#     Environment:
#       REDIS_AUTH_ENABLED:  true
#       REDIS_USERNAME:      <set to the key 'REDIS_USERNAME' in secret 'redis-auth'>  Optional: false
#       REDIS_PASSWORD:      <set to the key 'REDIS_PASSWORD' in secret 'redis-auth'>  Optional: false
#     Mounts:
#       /data from data (rw)
#       /usr/local/etc/redis from config (rw)
#       /var/run/secrets/kubernetes.io/serviceaccount from kube-api-access-xktg8 (ro)
# Conditions:
#   Type                        Status
#   PodReadyToStartContainers   True
#   Initialized                 True
#   Ready                       True
#   ContainersReady             True
#   PodScheduled                True
# Volumes:
#   config:
#     Type:      ConfigMap (a volume populated by a ConfigMap)
#     Name:      redis-config
#     Optional:  false
#   data:
#     Type:       PersistentVolumeClaim (a reference to a PersistentVolumeClaim in the same namespace)
#     ClaimName:  redis-data
#     ReadOnly:   false
#   kube-api-access-xktg8:
#     Type:                    Projected (a volume that contains injected data from multiple sources)
#     TokenExpirationSeconds:  3607
#     ConfigMapName:           kube-root-ca.crt
#     Optional:                false
#     DownwardAPI:             true
# QoS Class:                   Burstable
# Node-Selectors:              <none>
# Tolerations:                 node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                              node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
# Events:                      <none>
