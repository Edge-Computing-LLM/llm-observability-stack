# %%
from IPython.display import display, HTML

display(HTML("""
<style>
    /* Target the specific container for shell/terminal output */
    .jp-OutputArea-output pre {
        white-space: pre !important;
        overflow-x: auto !important;
        display: block !important;
        width: max-content;
        min-width: 100%;
    }
    /* Ensure the output area itself allows the scrollbar */
    .jp-OutputArea-child {
        overflow-x: auto !important;
    }
</style>
"""))
# Out:
# <style>
#     /* Target the specific container for shell/terminal output */
#     .jp-OutputArea-output pre {
#         white-space: pre !important;
#         overflow-x: auto !important;
#         display: block !important;
#         width: max-content;
#         min-width: 100%;
#     }
#     /* Ensure the output area itself allows the scrollbar */
#     .jp-OutputArea-child {
#         overflow-x: auto !important;
#     }
# </style>

# %%
#Run this command in linux terminal only. 
#!kubectl exec -it -n llm-observability langchain-demo-5dc95b9dbf-8ttrx -- /bin/bash

# %%
# !curl 127.0.0.1:8001/version
# Out:
# {
#   "major": "1",
#   "minor": "34",
#   "emulationMajor": "1",
#   "emulationMinor": "34",
#   "minCompatibilityMajor": "1",
#   "minCompatibilityMinor": "33",
#   "gitVersion": "v1.34.5+k3s1",
#   "gitCommit": "c2661bc1e7029f4e68a02f4a9d15c7de3428d0cf",
#   "gitTreeState": "clean",
#   "buildDate": "2026-03-04T18:39:37Z",
#   "goVersion": "go1.24.13",
#   "compiler": "gc",
#   "platform": "linux/amd64"
# }

# %%
#!helm upgrade --install llm-observability-stack . -n llm-observability -f values.local-k3s.yaml

# %%
# !kubectl get pods -n llm-observability
# Out:
# NAME                              READY   STATUS                     RESTARTS      AGE
# langchain-demo-5dc95b9dbf-8ttrx   1/1     Running                    1 (11h ago)   17h
# ollama-f4f5c6bfc-gqxnn            1/1     Running                    0             12m
# ollama-f4f5c6bfc-hwndk            0/1     UnexpectedAdmissionError   0             17h
# open-webui-0                      1/1     Running                    1 (12m ago)   18h
# redis-74f6bcc68f-hr2kl            1/1     Running                    9 (12m ago)   2d19h

# %%
# !kubectl describe pod langchain-demo-5dc95b9dbf-8ttrx -n llm-observability
# Out:
# Name:             langchain-demo-5dc95b9dbf-8ttrx
# Namespace:        llm-observability
# Priority:         0
# Service Account:  default
# Node:             waqasm86/192.168.18.45
# Start Time:       Sun, 22 Mar 2026 20:01:12 +0500
# Labels:           app.kubernetes.io/name=langchain-demo
#                   pod-template-hash=5dc95b9dbf
# Annotations:      <none>
# Status:           Running
# IP:               10.42.0.104
# IPs:
#   IP:           10.42.0.104
# Controlled By:  ReplicaSet/langchain-demo-5dc95b9dbf
# Containers:
#   app:
#     Container ID:  containerd://729c94058895fde4922e18ff6af22942711e11859b02934245e20736faf4117a
#     Image:         langchain-demo:0.1.0
#     Image ID:      sha256:ba7d1f2f803678bc860c4cde3dcb1555e2657cdb40b910d18157324a17509d8a
#     Port:          8000/TCP (http)
#     Host Port:     0/TCP (http)
#     Command:
#       python
#       -m
#       uvicorn
#       app:app
#       --host
#       0.0.0.0
#       --port
#       8000
#       --workers
#       1
#     State:          Running
#       Started:      Mon, 23 Mar 2026 13:35:46 +0500
#     Last State:     Terminated
#       Reason:       Completed
#       Exit Code:    0
#       Started:      Sun, 22 Mar 2026 20:01:13 +0500
#       Finished:     Mon, 23 Mar 2026 02:27:07 +0500
#     Ready:          True
#     Restart Count:  1
#     Limits:
#       cpu:     1
#       memory:  1Gi
#     Requests:
#       cpu:      250m
#       memory:   512Mi
#     Liveness:   http-get http://:http/healthz delay=40s timeout=1s period=20s #success=1 #failure=3
#     Readiness:  http-get http://:http/healthz delay=20s timeout=1s period=10s #success=1 #failure=3
#     Startup:    http-get http://:http/healthz delay=30s timeout=1s period=10s #success=1 #failure=36
#     Environment:
#       OLLAMA_BASE_URL:               http://ollama:11434
#       OLLAMA_UPSTREAM_BASE_URL:      http://ollama:11434
#       OLLAMA_MODEL:                  gemma3-1b-it-gguf-local
#       OLLAMA_PROXY_PATH_PREFIX:      /ollama
#       OLLAMA_PROXY_TRACE_LANGSMITH:  true
#       OLLAMA_PROXY_TIMEOUT_SECONDS:  180
#       LANGSMITH_TRACING:             true
#       LANGCHAIN_TRACING_V2:          true
#       LANGSMITH_ENDPOINT:            https://api.smith.langchain.com
#       LANGCHAIN_ENDPOINT:            https://api.smith.langchain.com
#       LANGSMITH_PROJECT:             k3s-ollama-gemma-local
#       LANGCHAIN_PROJECT:             k3s-ollama-gemma-local
#       LANGSMITH_API_KEY:             <set to the key 'LANGSMITH_API_KEY' in secret 'langsmith-secrets'>  Optional: false
#       LANGCHAIN_API_KEY:             <set to the key 'LANGSMITH_API_KEY' in secret 'langsmith-secrets'>  Optional: false
#     Mounts:
#       /app/app.py from app-code (ro,path="app.py")
#       /var/run/secrets/kubernetes.io/serviceaccount from kube-api-access-brcxt (ro)
# Conditions:
#   Type                        Status
#   PodReadyToStartContainers   True
#   Initialized                 True
#   Ready                       True
#   ContainersReady             True
#   PodScheduled                True
# Volumes:
#   app-code:
#     Type:      ConfigMap (a volume populated by a ConfigMap)
#     Name:      langchain-demo-app
#     Optional:  false
#   kube-api-access-brcxt:
#     Type:                    Projected (a volume that contains injected data from multiple sources)
#     TokenExpirationSeconds:  3607
#     ConfigMapName:           kube-root-ca.crt
#     Optional:                false
#     DownwardAPI:             true
# QoS Class:                   Burstable
# Node-Selectors:              <none>
# Tolerations:                 node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                              node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
# Events:
#   Type    Reason          Age   From     Message
#   ----    ------          ----  ----     -------
#   Normal  SandboxChanged  12m   kubelet  Pod sandbox changed, it will be killed and re-created.
#   Normal  Pulled          12m   kubelet  Container image "langchain-demo:0.1.0" already present on machine
#   Normal  Created         12m   kubelet  Created container: app
#   Normal  Started         12m   kubelet  Started container app

# %%
# !kubectl config view
# Out:
# apiVersion: v1
# clusters:
# - cluster:
#     certificate-authority-data: DATA+OMITTED
#     server: https://127.0.0.1:6443
#   name: default
# contexts:
# - context:
#     cluster: default
#     user: default
#   name: default
# current-context: default
# kind: Config
# users:
# - name: default
#   user:
#     client-certificate-data: DATA+OMITTED
#     client-key-data: DATA+OMITTED
