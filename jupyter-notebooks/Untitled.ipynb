# %%
from IPython.display import display, HTML

display(HTML("""
<style>
    /* Target the specific container for shell/terminal output */
    .jp-OutputArea-output pre {
        white-space: pre !important;
        overflow-x: auto !important;
        display: block !important;
        width: max-content;
        min-width: 100%;
    }
    /* Ensure the output area itself allows the scrollbar */
    .jp-OutputArea-child {
        overflow-x: auto !important;
    }
</style>
"""))
# Out:
# <style>
#     /* Target the specific container for shell/terminal output */
#     .jp-OutputArea-output pre {
#         white-space: pre !important;
#         overflow-x: auto !important;
#         display: block !important;
#         width: max-content;
#         min-width: 100%;
#     }
#     /* Ensure the output area itself allows the scrollbar */
#     .jp-OutputArea-child {
#         overflow-x: auto !important;
#     }
# </style>

# %%
from kubernetes import client, config

# Configs can be set in Configuration class directly or using helper utility
config.load_kube_config()

v1 = client.CoreV1Api()
print("Listing pods with their IPs:")
ret = v1.list_pod_for_all_namespaces(watch=False)
for i in ret.items:
    print("%s\t%s\t%s" % (i.status.pod_ip, i.metadata.namespace, i.metadata.name))
# Out:
# Listing pods with their IPs:
# 10.42.0.67	kube-system	coredns-695cbbfcb9-69w4k
# 10.42.0.69	kube-system	local-path-provisioner-546dfc6456-cbtgj
# 10.42.0.62	kube-system	metrics-server-c8774f4f4-z6lpm
# 10.42.0.73	kube-system	svclb-open-webui-b3bbb697-s889q
# 10.42.0.96	llm-observability	langchain-demo-5dc95b9dbf-8ttrx
# 10.42.0.92	llm-observability	ollama-f4f5c6bfc-hwndk
# 10.42.0.79	llm-observability	open-webui-0
# 10.42.0.64	llm-observability	redis-74f6bcc68f-hr2kl
# 10.42.0.63	nvidia-device-plugin	nvdp-node-feature-discovery-master-798cdbb948-7hpvg
# 10.42.0.70	nvidia-device-plugin	nvdp-node-feature-discovery-worker-nwmm8
# 10.42.0.71	nvidia-device-plugin	nvdp-nvidia-device-plugin-gpu-feature-discovery-pxw5v
# 10.42.0.74	nvidia-device-plugin	nvdp-nvidia-device-plugin-mps-control-daemon-8t5p7
# 10.42.0.72	nvidia-device-plugin	nvdp-nvidia-device-plugin-nc24z

# %%
from kubernetes import client, config, watch

# Configs can be set in Configuration class directly or using helper utility
config.load_kube_config()

v1 = client.CoreV1Api()
count = 10
w = watch.Watch()
for event in w.stream(v1.list_namespace, _request_timeout=60):
    print("Event: %s %s" % (event['type'], event['object'].metadata.name))
    count -= 1
    if not count:
        w.stop()

print("Ended.")
# Out:
# Event: ADDED default
# Event: ADDED kube-node-lease
# Event: ADDED kube-public
# Event: ADDED kube-system
# Event: ADDED llm-observability
# Event: ADDED nvidia-device-plugin
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:903, in HTTPResponse._error_catcher(self)
#     902 try:
# --> 903     yield
#     905 except SocketTimeout as e:
#     906     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     907     # there is yet no clean way to get at it from this context.
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:1418, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1417 else:
# -> 1418     self._update_chunk_length()
#    1419     if self.chunk_left == 0:
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:1333, in HTTPResponse._update_chunk_length(self)
#    1332     return None
# -> 1333 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1334 line = line.split(b";", 1)[0]
#
# File /usr/local/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     717 try:
# --> 718     return self._sock.recv_into(b)
#     719 except timeout:
#
# File /usr/local/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#
# File /usr/local/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1165 if buffer is not None:
# -> 1166     return self._sslobj.read(len, buffer)
#    1167 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# Cell In[3], line 9
#       7 count = 10
#       8 w = watch.Watch()
# ----> 9 for event in w.stream(v1.list_namespace, _request_timeout=60):
#      10     print("Event: %s %s" % (event['type'], event['object'].metadata.name))
#      11     count -= 1
#
# File ~/.local/lib/python3.11/site-packages/kubernetes/watch/watch.py:186, in Watch.stream(self, func, *args, **kwargs)
#     184 resp = func(*args, **kwargs)
#     185 try:
# --> 186     for line in iter_resp_lines(resp):
#     187         # unmarshal when we are receiving events from watch,
#     188         # return raw string when we are streaming log
#     189         if watch_arg == "watch":
#     190             if deserialize:
#
# File ~/.local/lib/python3.11/site-packages/kubernetes/watch/watch.py:56, in iter_resp_lines(resp)
#      54 def iter_resp_lines(resp):
#      55     buffer = bytearray()
# ---> 56     for segment in resp.stream(amt=None, decode_content=False):
#      57
#      58         # Append the segment (chunk) to the buffer
#      59         #
#      60         # Performance note: depending on contents of buffer and the type+value of segment,
#      61         # encoding segment into the buffer could be a wasteful step. The approach used here
#      62         # simplifies the logic farther down, but in the future it may be reasonable to
#      63         # sacrifice readability for performance.
#      64         if isinstance(segment, bytes):
#      65             buffer.extend(segment)
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:1250, in HTTPResponse.stream(self, amt, decode_content)
#    1234 """
#    1235 A generator wrapper for the read() method. A call will block until
#    1236 ``amt`` bytes have been read from the connection or until the
#    (...)   1247     'content-encoding' header.
#    1248 """
#    1249 if self.chunked and self.supports_chunked_reads():
# -> 1250     yield from self.read_chunked(amt, decode_content=decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:1397, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1391 if not self.supports_chunked_reads():
#    1392     raise BodyNotHttplibCompatible(
#    1393         "Body should be http.client.HTTPResponse like. "
#    1394         "It should have have an fp attribute which returns raw chunks."
#    1395     )
# -> 1397 with self._error_catcher():
#    1398     # Don't bother reading the body of a HEAD request.
#    1399     if self._original_response and is_response_to_head(self._original_response):
#    1400         self._original_response.close()
#
# File /usr/local/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~/.local/lib/python3.11/site-packages/urllib3/response.py:908, in HTTPResponse._error_catcher(self)
#     903     yield
#     905 except SocketTimeout as e:
#     906     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     907     # there is yet no clean way to get at it from this context.
# --> 908     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     910 except BaseSSLError as e:
#     911     # FIXME: Is there a better way to differentiate between SSLErrors?
#     912     if "read operation timed out" not in str(e):
#     913         # SSL errors related to framing/MAC get wrapped and reraised here
#
# ReadTimeoutError: HTTPSConnectionPool(host='127.0.0.1', port=6443): Read timed out.
